# %% [markdown]
# # Instrument identification granularity

# %% [markdown]
# ### Attested labels

# %% [markdown]
# Instrument categories (classes) attested in the current Cytomine dataset are listed in `classes.txt`:

# %%
items = []
for line in open('classes.txt'):
    line = line.strip()
    if not line:
        continue
    idx, rest = line.split(',')
    instrument, code = [i.strip() for i in rest.split('(')]
    code = code.replace(')', '')
    items.append((idx, instrument, code))

# %% [markdown]
# We convert this to a cleaner format:

# %%
import pandas as pd
df = pd.DataFrame(items, columns=('index', 'instrument', 'mimo'))
df = df.set_index('index')
df.to_csv('classes.csv')
df.head(10)
# Out:
#          instrument  mimo
# index
# 0           Cornett  3868
# 1              Viol  3597
# 2          Galoubet  3970
# 3          Clarinet  3836
# 4             Aulos  4173
# 5      Bladder pipe  3748
# 6            Fiddle  3142
# 7            Lirone  3183
# 8              Horn  4118
# 9          Mandolin  3510

# %%
df = pd.read_csv('classes.csv')
df = df.set_index('index')
df.head(10)
# Out:
#          instrument  mimo
# index
# 0           Cornett  3868
# 1              Viol  3597
# 2          Galoubet  3970
# 3          Clarinet  3836
# 4             Aulos  4173
# 5      Bladder pipe  3748
# 6            Fiddle  3142
# 7            Lirone  3183
# 8              Horn  4118
# 9          Mandolin  3510

# %% [markdown]
# ### Mimo thesaurus: 3-level hierarchy

# %% [markdown]
# We consult the MIMO thesaurus in the spreadsheet provided here: [link to repository](https://github.com/philharmoniedeparis/mimo/blob/master/harvesting/Docs/MIMO_Thesaurus.xlsx).

# %%
df = pd.read_excel('MIMO_Thesaurus.xlsx')
df.head(20)
# Out:
#           Identifier                 Level_1                 Level_2  \
# 0   LEXICON_00002208  Electronic instruments  Electronic instruments
# 1   LEXICON_00002209  Electronic instruments              Electronic
# 2   LEXICON_00006617  Electronic instruments              Electronic
# 3   LEXICON_00006618  Electronic instruments              Electronic
# 4   LEXICON_00006619  Electronic instruments              Electronic
# 5   LEXICON_00002210  Electronic instruments              Electronic
# 6   LEXICON_00002211  Electronic instruments              Electronic
# 7   LEXICON_00005903  Electronic instruments              Electronic
# 8   LEXICON_00002212  Electronic instruments              Electronic
# 9   LEXICON_00002213  Electronic instruments              Electronic
# 10  LEXICON_00002214  Electronic instruments              Electronic
# 11  LEXICON_00002215  Electronic instruments              Electronic
# 12  LEXICON_00006118  Electronic instruments              Electronic
# 13  LEXICON_00002216  Electronic instruments              Electronic
# 14  LEXICON_00002217  Electronic instruments              Electronic
# 15  LEXICON_00002219  Electronic instruments              Electronic
# 16  LEXICON_00002220  Electronic instruments              Electronic
# 17  LEXICON_00002221  Electronic instruments              Electronic
# 18  LEXICON_00002222  Electronic instruments              Electronic
# 19  LEXICON_00002223  Electronic instruments              Electronic
#
#                              Level_3     Synonyms  YOUR LANGUAGE  \
# 0             Electronic instruments          NaN            NaN
# 1                         Electronic          NaN            NaN
# 2                      Accord guitar          NaN            NaN
# 3              Accordion-synthesizer          NaN            NaN
# 4   Assemblage of electronic modules          NaN            NaN
# 5                            Beatbox          NaN            NaN
# 6                         Clavioline          NaN            NaN
# 7                       Croix sonore  Sound cross            NaN
# 8                         Gmebaphone          NaN            NaN
# 9                         Gmebogosse          NaN            NaN
# 10                         Heliophon          NaN            NaN
# 11                         Mellotron          NaN            NaN
# 12                       MIDI guitar          NaN            NaN
# 13                   MIDI instrument          NaN            NaN
# 14                    Ondes Martenot          NaN            NaN
# 15                         Ondioline          NaN            NaN
# 16                         Pianoline          NaN            NaN
# 17                           Sackbut          NaN            NaN
# 18                           Sampler          NaN            NaN
# 19                           Solovox          NaN            NaN
#
#     Synonyms (YOUR LANGUAGE)           H&S link  Nb of instruments Définition  \
# 0                         NaN               NaN                  0        NaN
# 1                         NaN  LEXICON_00006180                  0        NaN
# 2                         NaN               NaN                  0        NaN
# 3                         NaN               NaN                  3        NaN
# 4                         NaN  LEXICON_00006185                  0        NaN
# 5                         NaN               NaN                  4        NaN
# 6                         NaN  LEXICON_00006169                  3        NaN
# 7                         NaN               NaN                  1        NaN
# 8                         NaN               NaN                  1        NaN
# 9                         NaN               NaN                  0        NaN
# 10                        NaN               NaN                  0        NaN
# 11                        NaN  LEXICON_00006165                  2        NaN
# 12                        NaN               NaN                  1        NaN
# 13                        NaN               NaN                  2        NaN
# 14                        NaN  LEXICON_00006169                  7        NaN
# 15                        NaN  LEXICON_00006169                  5        NaN
# 16                        NaN               NaN                  0        NaN
# 17                        NaN               NaN                  0        NaN
# 18                        NaN               NaN                  1        NaN
# 19                        NaN               NaN                  1        NaN
#
#    Original language URI_DBPEDIA
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# 5                NaN         NaN
# 6             French         NaN
# 7                NaN         NaN
# 8             French         NaN
# 9             French         NaN
# 10               NaN         NaN
# 11               NaN         NaN
# 12               NaN         NaN
# 13               NaN         NaN
# 14            French         NaN
# 15            French         NaN
# 16               NaN         NaN
# 17               NaN         NaN
# 18               NaN         NaN
# 19               NaN         NaN

# %% [markdown]
# A class to convert an instrument name:

# %%
class Oracle(object):
    def __init__(self, path='MIMO_Thesaurus.xlsx'):
        super().__init__()
        df = pd.read_excel(path)
        self.lookup = {}
        for l1, l2, l3 in zip(df['Level_1'], df['Level_2'], df['Level_3']):
            l1 = ' '.join(l1.split())
            l2 = ' '.join(l2.split())
            l3 = ' '.join(l3.split())

            self.lookup[l3] = (l1, l2)
    
    def convert(self, q, level=2):
        assert level in (1, 2, 3)
        if q in self.lookup:
            if level == 3:
                return q
            else:
                l1, l2 = self.lookup[q]
                if level == 2:
                    return ' > '.join((l1, l2))
                elif level == 1:
                    return l1
            return q
        else:
            print(f'-> "{q}" not found')

# %%
oracle = Oracle()
print(oracle.convert('Pianoline'))
print(oracle.convert('Pianoline', level=1))
print(oracle.convert('Pianoline', level=2))
print(oracle.convert('Pianoline', level=3))
# Out:
# Electronic instruments > Electronic
# Electronic instruments
# Electronic instruments > Electronic
# Pianoline

# %% [markdown]
# ### Application

# %%
oracle = Oracle()
attested = pd.read_csv('classes.csv')['instrument'].tolist()

# %%
for instrument in attested:
    print(instrument, '> 1:', oracle.convert(instrument, level=1), ' 2:', oracle.convert(instrument, level=2))
# Out:
# Cornett > 1: Wind instruments  2: Wind instruments > Cornetts
# Viol > 1: Stringed instruments  2: Stringed instruments > Viols
# Galoubet > 1: Wind instruments  2: Wind instruments > Flutes
# Clarinet > 1: Wind instruments  2: Wind instruments > Clarinets
# Aulos > 1: Wind instruments  2: Wind instruments > Oboes
# Bladder pipe > 1: Wind instruments  2: Wind instruments > Bagpipes
# Fiddle > 1: Stringed instruments  2: Stringed instruments > Fiddles
# Lirone > 1: Stringed instruments  2: Stringed instruments > Fiddles
# Horn > 1: Wind instruments  2: Wind instruments > Horns
# Mandolin > 1: Stringed instruments  2: Stringed instruments > Mandolins
# Rattle > 1: Percussion instruments  2: Percussion instruments > Rattles
# Bagpipe > 1: Wind instruments  2: Wind instruments > Bagpipes
# Panpipe > 1: Wind instruments  2: Wind instruments > Flutes
# Organ > 1: Keyboard instruments  2: Keyboard instruments > Organs
# Drum > 1: Percussion instruments  2: Percussion instruments > Drums
# Percussion instruments > 1: Percussion instruments  2: Percussion instruments > Percussion instruments
# Tympanon > 1: Stringed instruments  2: Stringed instruments > Zithers
# Lyre > 1: Stringed instruments  2: Stringed instruments > Lyres
# Bassoon > 1: Wind instruments  2: Wind instruments > Bassoons
# Upright pianoforte > 1: Keyboard instruments  2: Keyboard instruments > Pianofortes
# Tambourine > 1: Percussion instruments  2: Percussion instruments > Drums
# Flute > 1: Wind instruments  2: Wind instruments > Flutes
# Cittern > 1: Stringed instruments  2: Stringed instruments > Citterns
# Theorbo > 1: Stringed instruments  2: Stringed instruments > Lutes
# Keyboard instruments > 1: Keyboard instruments  2: Keyboard instruments > Keyboard instruments
# Double bass > 1: Stringed instruments  2: Stringed instruments > Double basses
# Colascione > 1: Stringed instruments  2: Stringed instruments > Lutes
# Clavichord > 1: Keyboard instruments  2: Keyboard instruments > Clavichords
# Handbell > 1: Percussion instruments  2: Percussion instruments > Bells
# Whistle > 1: Wind instruments  2: Wind instruments > Flutes
# Bass drum > 1: Percussion instruments  2: Percussion instruments > Drums
# Gittern > 1: Stringed instruments  2: Stringed instruments > Lutes
# Double flute > 1: Wind instruments  2: Wind instruments > Flutes
# Positive organ > 1: Keyboard instruments  2: Keyboard instruments > Organs
# Dulcimer > 1: Stringed instruments  2: Stringed instruments > Zithers
# Zither > 1: Stringed instruments  2: Stringed instruments > Zithers
# Sackbut > 1: Electronic instruments  2: Electronic instruments > Electronic
# Kettledrum > 1: Percussion instruments  2: Percussion instruments > Kettledrums
# Cylindrical drum > 1: Percussion instruments  2: Percussion instruments > Drums
# Trombone > 1: Wind instruments  2: Wind instruments > Trombones
# Slide trumpet > 1: Wind instruments  2: Wind instruments > Trumpets
# Frame drum > 1: Percussion instruments  2: Percussion instruments > Drums
# End-blown horn > 1: Wind instruments  2: Wind instruments > Horns
# Chamber organ > 1: Keyboard instruments  2: Keyboard instruments > Organs
# Alphorn > 1: Wind instruments  2: Wind instruments > Trumpets
# Virginal > 1: Keyboard instruments  2: Keyboard instruments > Harpsichords
# Shawm > 1: Wind instruments  2: Wind instruments > Oboes
# Barbiton > 1: Stringed instruments  2: Stringed instruments > Lyres
# Fife > 1: Wind instruments  2: Wind instruments > Flutes
# Harp > 1: Stringed instruments  2: Stringed instruments > Harps
# Side drum > 1: Percussion instruments  2: Percussion instruments > Drums
# Harpsichord > 1: Keyboard instruments  2: Keyboard instruments > Harpsichords
# Natural trumpet > 1: Wind instruments  2: Wind instruments > Trumpets
# Guitar > 1: Stringed instruments  2: Stringed instruments > Guitars
# Natural horn > 1: Wind instruments  2: Wind instruments > Horns
# Lira da braccio > 1: Stringed instruments  2: Stringed instruments > Fiddles
# Triangle > 1: Percussion instruments  2: Percussion instruments > Others
# English guitar > 1: Stringed instruments  2: Stringed instruments > Citterns
# Clavicytherium > 1: Keyboard instruments  2: Keyboard instruments > Harpsichords
# Tuba > 1: Wind instruments  2: Wind instruments > Tubas
# Lute > 1: Stringed instruments  2: Stringed instruments > Lutes
# Transverse flute > 1: Wind instruments  2: Wind instruments > Flutes
# Qin > 1: Stringed instruments  2: Stringed instruments > Zithers
# Bell > 1: Percussion instruments  2: Percussion instruments > Bells
# Psaltery > 1: Stringed instruments  2: Stringed instruments > Zithers
# Viola da gamba > 1: Stringed instruments  2: Stringed instruments > Viols
# Stringed instruments > 1: Stringed instruments  2: Stringed instruments > Stringed instruments
# Square pianoforte > 1: Keyboard instruments  2: Keyboard instruments > Pianofortes
# Pianoforte > 1: Keyboard instruments  2: Keyboard instruments > Pianofortes
# Conch-shell trumpet > 1: Wind instruments  2: Wind instruments > Trumpets
# Hurdy-gurdy > 1: Stringed instruments  2: Stringed instruments > Hurdy-gurdies
# Pianino > 1: Keyboard instruments  2: Keyboard instruments > Pianofortes
# Hunting horn > 1: Wind instruments  2: Wind instruments > Hunting horns
# Kithara > 1: Stringed instruments  2: Stringed instruments > Lyres
# Citole > 1: Stringed instruments  2: Stringed instruments > Lutes
# Wind instruments > 1: Wind instruments  2: Wind instruments > Wind instruments
# Rebec > 1: Stringed instruments  2: Stringed instruments > Fiddles
# Tabor pipe > 1: Wind instruments  2: Wind instruments > Flutes
# Nakers > 1: Percussion instruments  2: Percussion instruments > Kettledrums
# Trumpet > 1: Wind instruments  2: Wind instruments > Trumpets
# Recorder > 1: Wind instruments  2: Wind instruments > Flutes
# Castanets > 1: Percussion instruments  2: Percussion instruments > Castanets
# End-blown flute > 1: Wind instruments  2: Wind instruments > Flutes
# Bugle > 1: Wind instruments  2: Wind instruments > Bugles
# Flageolet > 1: Wind instruments  2: Wind instruments > Flutes
# Portative organ > 1: Keyboard instruments  2: Keyboard instruments > Organs
# Grand pianoforte > 1: Keyboard instruments  2: Keyboard instruments > Pianofortes
# Carillon > 1: Percussion instruments  2: Percussion instruments > Bells
# Arched harp > 1: Stringed instruments  2: Stringed instruments > Harps
# Cymbals > 1: Percussion instruments  2: Percussion instruments > Cymbals
# Kit > 1: Stringed instruments  2: Stringed instruments > Violins
# Dulcian > 1: Wind instruments  2: Wind instruments > Bassoons
# Violoncello > 1: Stringed instruments  2: Stringed instruments > Violoncellos
# Vihuela > 1: Stringed instruments  2: Stringed instruments > Guitars
# Duct flute > 1: Wind instruments  2: Wind instruments > Flutes
# Spinet > 1: Keyboard instruments  2: Keyboard instruments > Harpsichords
# Crwth > 1: Stringed instruments  2: Stringed instruments > Lyres
# Oboe > 1: Wind instruments  2: Wind instruments > Oboes
# Accordion > 1: Wind instruments  2: Wind instruments > Accordions
# End-blown trumpet > 1: Wind instruments  2: Wind instruments > Trumpets
# Jew's harp > 1: Percussion instruments  2: Percussion instruments > Jew's harps
# Musette > 1: Wind instruments  2: Wind instruments > Bagpipes
# Organistrum > 1: Stringed instruments  2: Stringed instruments > Hurdy-gurdies
# Violin > 1: Stringed instruments  2: Stringed instruments > Violins
